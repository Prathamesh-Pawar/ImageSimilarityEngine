# %%
import warnings
warnings.filterwarnings("ignore")
import torch
from torchvision import datasets, transforms
from torch.utils.data import Dataset
import random

to_pil_image = transforms.ToPILImage()

# Transform for CIFAR-10
transform = transforms.Compose([
    transforms.ToTensor(),
])

# Load CIFAR-10 dataset
cifar10_train = datasets.CIFAR10(root="./data", train=True, download=True, transform=transform)
cifar10_test = datasets.CIFAR10(root="./data", train=False, download=True, transform=transform)

# Organize CIFAR-10 dataset by class
class_to_images_train = {i: [] for i in range(10)}
labels_train = []
for idx, (image, label) in enumerate(cifar10_train):
    if idx == 10000:
        break
    class_to_images_train[label].append((image, label))
    labels_train.append(label)
    
labels_train = torch.tensor(labels_train)

class_to_images_test = {i: [] for i in range(10)}
labels_test = []
for idx, (image, label) in enumerate(cifar10_test):
    if idx == 1000:
        break
    class_to_images_test[label].append((image, label))
    labels_test.append(label)
    
labels_test = torch.tensor(labels_test)


# Custom dataset class
class TripletCIFAR10Dataset(Dataset):
    def __init__(self, labels, class_to_images, num_samples):
        self.train_labels = labels
        self.class_to_images = class_to_images
        self.num_samples = num_samples
        self.classes = list(class_to_images.keys())
    
    def __len__(self):
        return self.num_samples
    
    def __getitem__(self, idx):
        # Select a random class
        same_class = random.choice(self.classes)
        
        # Select two images from the same class
        img1, _ = random.choice(self.class_to_images[same_class])
        img2, _ = random.choice(self.class_to_images[same_class])
        
        # Select a different class
        diff_class = random.choice([c for c in self.classes if c != same_class])
        
        # Select one image from the different class
        img3, _ = random.choice(self.class_to_images[diff_class])
        
        # Return triplet (img1, img2, img3) and label (same_class)
        return (img1, img2, img3), same_class

# Create datasets
train_size, test_size = 5000, 1000
train_dataset = TripletCIFAR10Dataset(labels_train, class_to_images_train, train_size)
test_dataset = TripletCIFAR10Dataset(labels_test, class_to_images_test, test_size)

print("Datasets created successfully!")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Datasets created successfully!

# %%
from datasets_s import BalancedBatchSampler

# We'll create mini batches by sampling labels that will be present in the mini batch and number of examples from each class
train_batch_sampler = BalancedBatchSampler(torch.tensor(cifar10_train.targets), n_classes=10, n_samples=25)
test_batch_sampler = BalancedBatchSampler(torch.tensor(cifar10_test.targets), n_classes=10, n_samples=25)

online_train_loader = torch.utils.data.DataLoader(train_dataset, batch_sampler=train_batch_sampler)
online_test_loader = torch.utils.data.DataLoader(test_dataset, batch_sampler=test_batch_sampler)

# %%
from torch.optim import lr_scheduler
from torch import optim
from networks import EmbeddingNet, TripletNet
from losses import OnlineTripletLoss
from utils import  SemihardNegativeTripletSelector
from metrics import AverageNonzeroTripletsMetric

margin = 1.
embedding_net = EmbeddingNet()
model = TripletNet(embedding_net)

loss_fn = OnlineTripletLoss(margin, SemihardNegativeTripletSelector(margin))
lr = 1e-3
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 50
log_interval = 50

# %%
from trainer import fit

fit(online_train_loader, online_test_loader, model, loss_fn, optimizer, scheduler, n_epochs, None, log_interval, metrics=[AverageNonzeroTripletsMetric()])
# Out:
# Train: [0/5000 (0%)]	Loss: 0.999727	Average nonzero triplets: 3193.0
# Train: [12500/5000 (25%)]	Loss: 0.530934	Average nonzero triplets: 851.7647058823529
# Train: [25000/5000 (50%)]	Loss: 0.504443	Average nonzero triplets: 535.009900990099
# Train: [37500/5000 (75%)]	Loss: 20229.008116	Average nonzero triplets: 407.50331125827813
# Epoch: 1/50. Train set: Average loss: 5083.0532	Average nonzero triplets: 366.91959798994975
# Epoch: 1/50. Validation set: Average loss: 0.4852	Average nonzero triplets: 137.89743589743588
# Train: [0/5000 (0%)]	Loss: 0.507209	Average nonzero triplets: 235.0
# Train: [12500/5000 (25%)]	Loss: 0.497160	Average nonzero triplets: 171.2941176470588
# Train: [25000/5000 (50%)]	Loss: 0.501031	Average nonzero triplets: 364.28712871287127
# Train: [37500/5000 (75%)]	Loss: 0.500013	Average nonzero triplets: 375.5298013245033
# Epoch: 2/50. Train set: Average loss: 0.5005	Average nonzero triplets: 361.48743718592965
# Epoch: 2/50. Validation set: Average loss: 0.4825	Average nonzero triplets: 276.43589743589746
# Train: [0/5000 (0%)]	Loss: 0.515230	Average nonzero triplets: 300.0
# Train: [12500/5000 (25%)]	Loss: 0.497243	Average nonzero triplets: 228.37254901960785
# Train: [25000/5000 (50%)]	Loss: 0.506299	Average nonzero triplets: 208.75247524752476
# Train: [37500/5000 (75%)]	Loss: 0.499413	Average nonzero triplets: 201.50331125827816
# Epoch: 3/50. Train set: Average loss: 0.5011	Average nonzero triplets: 217.98994974874373
# Epoch: 3/50. Validation set: Average loss: 0.4828	Average nonzero triplets: 231.15384615384616
# Train: [0/5000 (0%)]	Loss: 0.505964	Average nonzero triplets: 248.0
# Train: [12500/5000 (25%)]	Loss: 0.504625	Average nonzero triplets: 267.94117647058823
# Train: [25000/5000 (50%)]	Loss: 0.501396	Average nonzero triplets: 245.5049504950495
# Train: [37500/5000 (75%)]	Loss: 0.499726	Average nonzero triplets: 246.1523178807947
# Epoch: 4/50. Train set: Average loss: 0.5017	Average nonzero triplets: 259.56281407035175
# Epoch: 4/50. Validation set: Average loss: 0.4846	Average nonzero triplets: 240.6153846153846
# Train: [0/5000 (0%)]	Loss: 0.497185	Average nonzero triplets: 269.0
# Train: [12500/5000 (25%)]	Loss: 0.502094	Average nonzero triplets: 284.9019607843137
# Train: [25000/5000 (50%)]	Loss: 0.495501	Average nonzero triplets: 313.7029702970297
# Train: [37500/5000 (75%)]	Loss: 0.499679	Average nonzero triplets: 353.8211920529801
# Epoch: 5/50. Train set: Average loss: 0.4996	Average nonzero triplets: 359.19095477386935
# Epoch: 5/50. Validation set: Average loss: 0.4876	Average nonzero triplets: 345.64102564102564
# Train: [0/5000 (0%)]	Loss: 0.508851	Average nonzero triplets: 380.0
# Train: [12500/5000 (25%)]	Loss: 0.503859	Average nonzero triplets: 445.7843137254902
# Train: [25000/5000 (50%)]	Loss: 0.501706	Average nonzero triplets: 413.18811881188117
# Train: [37500/5000 (75%)]	Loss: 0.505568	Average nonzero triplets: 389.52317880794703
# Epoch: 6/50. Train set: Average loss: 0.5024	Average nonzero triplets: 386.964824120603
# Epoch: 6/50. Validation set: Average loss: 0.4831	Average nonzero triplets: 310.87179487179486
# Train: [0/5000 (0%)]	Loss: 0.478860	Average nonzero triplets: 358.0
# Train: [12500/5000 (25%)]	Loss: 0.499140	Average nonzero triplets: 448.7450980392157
# Train: [25000/5000 (50%)]	Loss: 0.499188	Average nonzero triplets: 454.73267326732673
# Train: [37500/5000 (75%)]	Loss: 0.503496	Average nonzero triplets: 460.112582781457
# Epoch: 7/50. Train set: Average loss: 0.5005	Average nonzero triplets: 485.1758793969849
# Epoch: 7/50. Validation set: Average loss: 0.4842	Average nonzero triplets: 471.43589743589746
# Train: [0/5000 (0%)]	Loss: 0.503953	Average nonzero triplets: 551.0
# Train: [12500/5000 (25%)]	Loss: 0.496978	Average nonzero triplets: 530.6862745098039
# Train: [25000/5000 (50%)]	Loss: 0.500036	Average nonzero triplets: 552.2772277227723
# Train: [37500/5000 (75%)]	Loss: 0.500542	Average nonzero triplets: 557.2185430463576
# Epoch: 8/50. Train set: Average loss: 0.4997	Average nonzero triplets: 555.6884422110553
# Epoch: 8/50. Validation set: Average loss: 0.4841	Average nonzero triplets: 496.1025641025641
# Train: [0/5000 (0%)]	Loss: 0.491470	Average nonzero triplets: 662.0
# Train: [12500/5000 (25%)]	Loss: 0.500623	Average nonzero triplets: 563.4313725490196
# Train: [25000/5000 (50%)]	Loss: 0.501870	Average nonzero triplets: 570.8712871287129
# Train: [37500/5000 (75%)]	Loss: 0.501128	Average nonzero triplets: 575.317880794702
# Epoch: 9/50. Train set: Average loss: 0.5007	Average nonzero triplets: 579.6180904522613
# Epoch: 9/50. Validation set: Average loss: 0.4867	Average nonzero triplets: 532.8974358974359
# Train: [0/5000 (0%)]	Loss: 0.503377	Average nonzero triplets: 594.0
# Train: [12500/5000 (25%)]	Loss: 0.499680	Average nonzero triplets: 601.3921568627451
# Train: [25000/5000 (50%)]	Loss: 0.500008	Average nonzero triplets: 622.2079207920792
# Train: [37500/5000 (75%)]	Loss: 0.503024	Average nonzero triplets: 619.7284768211921
# Epoch: 10/50. Train set: Average loss: 0.5013	Average nonzero triplets: 624.5376884422111
# Epoch: 10/50. Validation set: Average loss: 0.4873	Average nonzero triplets: 612.2307692307693
# Train: [0/5000 (0%)]	Loss: 0.512873	Average nonzero triplets: 641.0
# Train: [12500/5000 (25%)]	Loss: 0.498101	Average nonzero triplets: 659.7254901960785
# Train: [25000/5000 (50%)]	Loss: 0.499779	Average nonzero triplets: 659.7821782178218
# Train: [37500/5000 (75%)]	Loss: 0.502423	Average nonzero triplets: 666.5761589403974
# Epoch: 11/50. Train set: Average loss: 0.5001	Average nonzero triplets: 668.1105527638191
# Epoch: 11/50. Validation set: Average loss: 0.4861	Average nonzero triplets: 629.4615384615385
# Train: [0/5000 (0%)]	Loss: 0.496745	Average nonzero triplets: 710.0
# Train: [12500/5000 (25%)]	Loss: 0.499005	Average nonzero triplets: 696.3333333333334
# Train: [25000/5000 (50%)]	Loss: 0.499769	Average nonzero triplets: 723.4554455445544
# Train: [37500/5000 (75%)]	Loss: 0.500317	Average nonzero triplets: 723.0
# Epoch: 12/50. Train set: Average loss: 0.4998	Average nonzero triplets: 723.1658291457286
# Epoch: 12/50. Validation set: Average loss: 0.4898	Average nonzero triplets: 713.0
# Train: [0/5000 (0%)]	Loss: 0.508000	Average nonzero triplets: 807.0
# Train: [12500/5000 (25%)]	Loss: 0.499666	Average nonzero triplets: 743.1764705882352
# Train: [25000/5000 (50%)]	Loss: 0.499401	Average nonzero triplets: 748.0891089108911
# Train: [37500/5000 (75%)]	Loss: 0.499614	Average nonzero triplets: 755.5960264900663
# Epoch: 13/50. Train set: Average loss: 0.4994	Average nonzero triplets: 747.1457286432161
# Epoch: 13/50. Validation set: Average loss: 0.4899	Average nonzero triplets: 677.0769230769231
# Train: [0/5000 (0%)]	Loss: 0.486021	Average nonzero triplets: 736.0
# Train: [12500/5000 (25%)]	Loss: 0.498418	Average nonzero triplets: 772.7843137254902
# Train: [25000/5000 (50%)]	Loss: 0.500602	Average nonzero triplets: 785.2178217821782
# Train: [37500/5000 (75%)]	Loss: 0.502305	Average nonzero triplets: 807.7417218543046
# Epoch: 14/50. Train set: Average loss: 0.4998	Average nonzero triplets: 819.1658291457286
# Epoch: 14/50. Validation set: Average loss: 0.4878	Average nonzero triplets: 814.3076923076923
# Train: [0/5000 (0%)]	Loss: 0.500624	Average nonzero triplets: 940.0
# Train: [12500/5000 (25%)]	Loss: 0.499945	Average nonzero triplets: 910.5294117647059
# Train: [25000/5000 (50%)]	Loss: 0.504614	Average nonzero triplets: 905.7128712871287
# Train: [37500/5000 (75%)]	Loss: 0.501416	Average nonzero triplets: 904.2913907284768
# Epoch: 15/50. Train set: Average loss: 0.5011	Average nonzero triplets: 918.3417085427136
# Epoch: 15/50. Validation set: Average loss: 0.4868	Average nonzero triplets: 908.7692307692307
# Train: [0/5000 (0%)]	Loss: 0.494581	Average nonzero triplets: 965.0
# Train: [12500/5000 (25%)]	Loss: 0.501203	Average nonzero triplets: 952.0392156862745
# Train: [25000/5000 (50%)]	Loss: 0.499797	Average nonzero triplets: 956.019801980198
# Train: [37500/5000 (75%)]	Loss: 0.499431	Average nonzero triplets: 957.841059602649
# Epoch: 16/50. Train set: Average loss: 0.4999	Average nonzero triplets: 958.7537688442211
# Epoch: 16/50. Validation set: Average loss: 0.4865	Average nonzero triplets: 887.6666666666666
# Train: [0/5000 (0%)]	Loss: 0.500900	Average nonzero triplets: 1030.0
# Train: [12500/5000 (25%)]	Loss: 0.499833	Average nonzero triplets: 956.2549019607843
# Train: [25000/5000 (50%)]	Loss: 0.501636	Average nonzero triplets: 947.5841584158416
# Train: [37500/5000 (75%)]	Loss: 0.500346	Average nonzero triplets: 949.6556291390729
# Epoch: 17/50. Train set: Average loss: 0.5010	Average nonzero triplets: 950.7386934673367
# Epoch: 17/50. Validation set: Average loss: 0.4866	Average nonzero triplets: 887.7692307692307
# Train: [0/5000 (0%)]	Loss: 0.495593	Average nonzero triplets: 909.0
# Train: [12500/5000 (25%)]	Loss: 0.500749	Average nonzero triplets: 963.3725490196078
# Train: [25000/5000 (50%)]	Loss: 0.502713	Average nonzero triplets: 956.7524752475248
# Train: [37500/5000 (75%)]	Loss: 0.498770	Average nonzero triplets: 956.2450331125827
# Epoch: 18/50. Train set: Average loss: 0.5006	Average nonzero triplets: 957.1758793969849
# Epoch: 18/50. Validation set: Average loss: 0.4893	Average nonzero triplets: 907.8717948717949
# Train: [0/5000 (0%)]	Loss: 0.475007	Average nonzero triplets: 949.0
# Train: [12500/5000 (25%)]	Loss: 0.500232	Average nonzero triplets: 968.1372549019608
# Train: [25000/5000 (50%)]	Loss: 0.501910	Average nonzero triplets: 966.5841584158416
# Train: [37500/5000 (75%)]	Loss: 0.500429	Average nonzero triplets: 962.1920529801324
# Epoch: 19/50. Train set: Average loss: 0.5007	Average nonzero triplets: 958.608040201005
# Epoch: 19/50. Validation set: Average loss: 0.4846	Average nonzero triplets: 900.4871794871794
# Train: [0/5000 (0%)]	Loss: 0.480076	Average nonzero triplets: 905.0
# Train: [12500/5000 (25%)]	Loss: 0.501511	Average nonzero triplets: 960.3529411764706
# Train: [25000/5000 (50%)]	Loss: 0.502598	Average nonzero triplets: 971.6633663366337
# Train: [37500/5000 (75%)]	Loss: 0.500457	Average nonzero triplets: 971.5629139072847
# Epoch: 20/50. Train set: Average loss: 0.5012	Average nonzero triplets: 970.2713567839196
# Epoch: 20/50. Validation set: Average loss: 0.4867	Average nonzero triplets: 896.6153846153846
# Train: [0/5000 (0%)]	Loss: 0.510499	Average nonzero triplets: 962.0
# Train: [12500/5000 (25%)]	Loss: 0.501056	Average nonzero triplets: 963.2549019607843
# Train: [25000/5000 (50%)]	Loss: 0.500773	Average nonzero triplets: 971.4158415841584
# Train: [37500/5000 (75%)]	Loss: 0.501305	Average nonzero triplets: 978.9933774834437
# Epoch: 21/50. Train set: Average loss: 0.5011	Average nonzero triplets: 983.4221105527638
# Epoch: 21/50. Validation set: Average loss: 0.4873	Average nonzero triplets: 928.1025641025641
# Train: [0/5000 (0%)]	Loss: 0.501600	Average nonzero triplets: 1044.0
# Train: [12500/5000 (25%)]	Loss: 0.497355	Average nonzero triplets: 999.8627450980392
# Train: [25000/5000 (50%)]	Loss: 0.501130	Average nonzero triplets: 1002.3366336633663
# Train: [37500/5000 (75%)]	Loss: 0.499869	Average nonzero triplets: 1000.6556291390729
# Epoch: 22/50. Train set: Average loss: 0.4993	Average nonzero triplets: 1005.929648241206
# Epoch: 22/50. Validation set: Average loss: 0.4863	Average nonzero triplets: 945.2307692307693
# Train: [0/5000 (0%)]	Loss: 0.510970	Average nonzero triplets: 952.0
# Train: [12500/5000 (25%)]	Loss: 0.500822	Average nonzero triplets: 1008.2352941176471
# Train: [25000/5000 (50%)]	Loss: 0.500683	Average nonzero triplets: 1013.980198019802
# Train: [37500/5000 (75%)]	Loss: 0.498682	Average nonzero triplets: 1017.5827814569536
# Epoch: 23/50. Train set: Average loss: 0.5000	Average nonzero triplets: 1017.5929648241206
# Epoch: 23/50. Validation set: Average loss: 0.4876	Average nonzero triplets: 948.6666666666666
# Train: [0/5000 (0%)]	Loss: 0.497105	Average nonzero triplets: 1064.0
# Train: [12500/5000 (25%)]	Loss: 0.500717	Average nonzero triplets: 1006.9411764705883
# Train: [25000/5000 (50%)]	Loss: 0.498927	Average nonzero triplets: 1002.6138613861386
# Train: [37500/5000 (75%)]	Loss: 0.501514	Average nonzero triplets: 1005.9006622516556
# Epoch: 24/50. Train set: Average loss: 0.5000	Average nonzero triplets: 1004.8542713567839
# Epoch: 24/50. Validation set: Average loss: 0.4900	Average nonzero triplets: 937.3333333333334
# Train: [0/5000 (0%)]	Loss: 0.502285	Average nonzero triplets: 1038.0
# Train: [12500/5000 (25%)]	Loss: 0.501950	Average nonzero triplets: 1007.8235294117648
# Train: [25000/5000 (50%)]	Loss: 0.501494	Average nonzero triplets: 1010.4158415841584
# Train: [37500/5000 (75%)]	Loss: 0.500328	Average nonzero triplets: 1008.7086092715232
# Epoch: 25/50. Train set: Average loss: 0.5013	Average nonzero triplets: 1008.8844221105528
# Epoch: 25/50. Validation set: Average loss: 0.4902	Average nonzero triplets: 963.0512820512821
# Train: [0/5000 (0%)]	Loss: 0.500045	Average nonzero triplets: 987.0
# Train: [12500/5000 (25%)]	Loss: 0.500041	Average nonzero triplets: 1017.9019607843137
# Train: [25000/5000 (50%)]	Loss: 0.501969	Average nonzero triplets: 1015.1386138613861
# Train: [37500/5000 (75%)]	Loss: 0.499960	Average nonzero triplets: 1014.8145695364238
# Epoch: 26/50. Train set: Average loss: 0.5003	Average nonzero triplets: 1012.6834170854271
# Epoch: 26/50. Validation set: Average loss: 0.4890	Average nonzero triplets: 968.4871794871794
# Train: [0/5000 (0%)]	Loss: 0.499928	Average nonzero triplets: 986.0
# Train: [12500/5000 (25%)]	Loss: 0.498031	Average nonzero triplets: 1024.686274509804
# Train: [25000/5000 (50%)]	Loss: 0.499721	Average nonzero triplets: 1021.3366336633663
# Train: [37500/5000 (75%)]	Loss: 0.498075	Average nonzero triplets: 1014.2582781456954
# Epoch: 27/50. Train set: Average loss: 0.4990	Average nonzero triplets: 1014.9045226130653
# Epoch: 27/50. Validation set: Average loss: 0.4888	Average nonzero triplets: 959.2564102564103
# Train: [0/5000 (0%)]	Loss: 0.514471	Average nonzero triplets: 983.0
# Train: [12500/5000 (25%)]	Loss: 0.500257	Average nonzero triplets: 1030.921568627451
# Train: [25000/5000 (50%)]	Loss: 0.501976	Average nonzero triplets: 1024.6534653465346
# Train: [37500/5000 (75%)]	Loss: 0.500521	Average nonzero triplets: 1020.1655629139073
# Epoch: 28/50. Train set: Average loss: 0.5010	Average nonzero triplets: 1021.0201005025126
# Epoch: 28/50. Validation set: Average loss: 0.4902	Average nonzero triplets: 940.7692307692307
# Train: [0/5000 (0%)]	Loss: 0.497605	Average nonzero triplets: 1084.0
# Train: [12500/5000 (25%)]	Loss: 0.499859	Average nonzero triplets: 1019.1372549019608
# Train: [25000/5000 (50%)]	Loss: 0.499434	Average nonzero triplets: 1029.4752475247524
# Train: [37500/5000 (75%)]	Loss: 0.500482	Average nonzero triplets: 1023.0132450331126
# Epoch: 29/50. Train set: Average loss: 0.4997	Average nonzero triplets: 1021.391959798995
# Epoch: 29/50. Validation set: Average loss: 0.4856	Average nonzero triplets: 958.8461538461538
# Train: [0/5000 (0%)]	Loss: 0.516767	Average nonzero triplets: 971.0
# Train: [12500/5000 (25%)]	Loss: 0.500740	Average nonzero triplets: 1025.5882352941176
# Train: [25000/5000 (50%)]	Loss: 0.499638	Average nonzero triplets: 1019.5148514851485
# Train: [37500/5000 (75%)]	Loss: 0.500471	Average nonzero triplets: 1020.0463576158941
# Epoch: 30/50. Train set: Average loss: 0.5007	Average nonzero triplets: 1020.929648241206
# Epoch: 30/50. Validation set: Average loss: 0.4903	Average nonzero triplets: 945.6666666666666
# Train: [0/5000 (0%)]	Loss: 0.493079	Average nonzero triplets: 1127.0
# Train: [12500/5000 (25%)]	Loss: 0.500749	Average nonzero triplets: 1025.5294117647059
# Train: [25000/5000 (50%)]	Loss: 0.500700	Average nonzero triplets: 1028.3267326732673
# Train: [37500/5000 (75%)]	Loss: 0.501553	Average nonzero triplets: 1031.1920529801325
# Epoch: 31/50. Train set: Average loss: 0.5000	Average nonzero triplets: 1030.7286432160804
# Epoch: 31/50. Validation set: Average loss: 0.4849	Average nonzero triplets: 954.0
# Train: [0/5000 (0%)]	Loss: 0.512536	Average nonzero triplets: 1102.0
# Train: [12500/5000 (25%)]	Loss: 0.499313	Average nonzero triplets: 1032.4313725490197
# Train: [25000/5000 (50%)]	Loss: 0.499044	Average nonzero triplets: 1021.1782178217821
# Train: [37500/5000 (75%)]	Loss: 0.500581	Average nonzero triplets: 1028.5298013245033
# Epoch: 32/50. Train set: Average loss: 0.4996	Average nonzero triplets: 1025.5829145728644
# Epoch: 32/50. Validation set: Average loss: 0.4873	Average nonzero triplets: 955.2564102564103
# Train: [0/5000 (0%)]	Loss: 0.490777	Average nonzero triplets: 982.0
# Train: [12500/5000 (25%)]	Loss: 0.502454	Average nonzero triplets: 1022.2156862745098
# Train: [25000/5000 (50%)]	Loss: 0.500984	Average nonzero triplets: 1021.990099009901
# Train: [37500/5000 (75%)]	Loss: 0.501549	Average nonzero triplets: 1025.6225165562914
# Epoch: 33/50. Train set: Average loss: 0.5010	Average nonzero triplets: 1023.6331658291457
# Epoch: 33/50. Validation set: Average loss: 0.4858	Average nonzero triplets: 970.0512820512821
# Train: [0/5000 (0%)]	Loss: 0.501320	Average nonzero triplets: 1041.0
# Train: [12500/5000 (25%)]	Loss: 0.500032	Average nonzero triplets: 1032.5882352941176
# Train: [25000/5000 (50%)]	Loss: 0.497694	Average nonzero triplets: 1023.8811881188119
# Train: [37500/5000 (75%)]	Loss: 0.500246	Average nonzero triplets: 1026.7019867549668
# Epoch: 34/50. Train set: Average loss: 0.4988	Average nonzero triplets: 1024.0854271356784
# Epoch: 34/50. Validation set: Average loss: 0.4879	Average nonzero triplets: 963.5128205128206
# Train: [0/5000 (0%)]	Loss: 0.497737	Average nonzero triplets: 996.0
# Train: [12500/5000 (25%)]	Loss: 0.498757	Average nonzero triplets: 1020.5490196078431
# Train: [25000/5000 (50%)]	Loss: 0.499397	Average nonzero triplets: 1012.9108910891089
# Train: [37500/5000 (75%)]	Loss: 0.499067	Average nonzero triplets: 1016.6423841059602
# Epoch: 35/50. Train set: Average loss: 0.4995	Average nonzero triplets: 1018.6231155778894
# Epoch: 35/50. Validation set: Average loss: 0.4870	Average nonzero triplets: 956.2564102564103
# Train: [0/5000 (0%)]	Loss: 0.493843	Average nonzero triplets: 1047.0
# Train: [12500/5000 (25%)]	Loss: 0.500971	Average nonzero triplets: 1030.0392156862745
# Train: [25000/5000 (50%)]	Loss: 0.500117	Average nonzero triplets: 1027.2178217821781
# Train: [37500/5000 (75%)]	Loss: 0.502826	Average nonzero triplets: 1022.8675496688742
# Epoch: 36/50. Train set: Average loss: 0.5013	Average nonzero triplets: 1028.356783919598
# Epoch: 36/50. Validation set: Average loss: 0.4907	Average nonzero triplets: 943.7435897435897
# Train: [0/5000 (0%)]	Loss: 0.504632	Average nonzero triplets: 1089.0
# Train: [12500/5000 (25%)]	Loss: 0.500218	Average nonzero triplets: 1030.9019607843138
# Train: [25000/5000 (50%)]	Loss: 0.500400	Average nonzero triplets: 1030.2970297029703
# Train: [37500/5000 (75%)]	Loss: 0.499853	Average nonzero triplets: 1030.8476821192053
# Epoch: 37/50. Train set: Average loss: 0.5003	Average nonzero triplets: 1027.8743718592964
# Epoch: 37/50. Validation set: Average loss: 0.4901	Average nonzero triplets: 980.9230769230769
# Train: [0/5000 (0%)]	Loss: 0.476263	Average nonzero triplets: 1068.0
# Train: [12500/5000 (25%)]	Loss: 0.499891	Average nonzero triplets: 1026.764705882353
# Train: [25000/5000 (50%)]	Loss: 0.499897	Average nonzero triplets: 1028.5841584158416
# Train: [37500/5000 (75%)]	Loss: 0.500375	Average nonzero triplets: 1024.5033112582782
# Epoch: 38/50. Train set: Average loss: 0.5005	Average nonzero triplets: 1022.4874371859296
# Epoch: 38/50. Validation set: Average loss: 0.4845	Average nonzero triplets: 969.8974358974359
# Train: [0/5000 (0%)]	Loss: 0.505582	Average nonzero triplets: 998.0
# Train: [12500/5000 (25%)]	Loss: 0.500204	Average nonzero triplets: 1035.4117647058824
# Train: [25000/5000 (50%)]	Loss: 0.497418	Average nonzero triplets: 1036.3267326732673
# Train: [37500/5000 (75%)]	Loss: 0.498114	Average nonzero triplets: 1032.841059602649
# Epoch: 39/50. Train set: Average loss: 0.4994	Average nonzero triplets: 1033.572864321608
# Epoch: 39/50. Validation set: Average loss: 0.4847	Average nonzero triplets: 961.5641025641025
# Train: [0/5000 (0%)]	Loss: 0.483056	Average nonzero triplets: 1065.0
# Train: [12500/5000 (25%)]	Loss: 0.499870	Average nonzero triplets: 1031.0392156862745
# Train: [25000/5000 (50%)]	Loss: 0.498099	Average nonzero triplets: 1026.2673267326732
# Train: [37500/5000 (75%)]	Loss: 0.499543	Average nonzero triplets: 1026.4437086092714
# Epoch: 40/50. Train set: Average loss: 0.4992	Average nonzero triplets: 1025.6130653266332
# Epoch: 40/50. Validation set: Average loss: 0.4867	Average nonzero triplets: 964.9487179487179
# Train: [0/5000 (0%)]	Loss: 0.499676	Average nonzero triplets: 975.0
# Train: [12500/5000 (25%)]	Loss: 0.500220	Average nonzero triplets: 1019.843137254902
# Train: [25000/5000 (50%)]	Loss: 0.498607	Average nonzero triplets: 1024.069306930693
# Train: [37500/5000 (75%)]	Loss: 0.500066	Average nonzero triplets: 1020.2582781456954
# Epoch: 41/50. Train set: Average loss: 0.5000	Average nonzero triplets: 1020.4020100502513
# Epoch: 41/50. Validation set: Average loss: 0.4868	Average nonzero triplets: 976.3846153846154
# Train: [0/5000 (0%)]	Loss: 0.508820	Average nonzero triplets: 1046.0
# Train: [12500/5000 (25%)]	Loss: 0.498897	Average nonzero triplets: 1033.235294117647
# Train: [25000/5000 (50%)]	Loss: 0.501685	Average nonzero triplets: 1023.8514851485148
# Train: [37500/5000 (75%)]	Loss: 0.500491	Average nonzero triplets: 1021.3377483443709
# Epoch: 42/50. Train set: Average loss: 0.5001	Average nonzero triplets: 1020.9447236180905
# Epoch: 42/50. Validation set: Average loss: 0.4861	Average nonzero triplets: 948.3846153846154
# Train: [0/5000 (0%)]	Loss: 0.492689	Average nonzero triplets: 1094.0
# Train: [12500/5000 (25%)]	Loss: 0.499371	Average nonzero triplets: 1013.6862745098039
# Train: [25000/5000 (50%)]	Loss: 0.499588	Average nonzero triplets: 1025.8217821782177
# Train: [37500/5000 (75%)]	Loss: 0.501448	Average nonzero triplets: 1028.8211920529802
# Epoch: 43/50. Train set: Average loss: 0.5001	Average nonzero triplets: 1030.5929648241206
# Epoch: 43/50. Validation set: Average loss: 0.4879	Average nonzero triplets: 967.8717948717949
# Train: [0/5000 (0%)]	Loss: 0.491632	Average nonzero triplets: 1029.0
# Train: [12500/5000 (25%)]	Loss: 0.500486	Average nonzero triplets: 1029.9019607843138
# Train: [25000/5000 (50%)]	Loss: 0.498452	Average nonzero triplets: 1027.920792079208
# Train: [37500/5000 (75%)]	Loss: 0.498936	Average nonzero triplets: 1029.7549668874171
# Epoch: 44/50. Train set: Average loss: 0.4991	Average nonzero triplets: 1029.4020100502512
# Epoch: 44/50. Validation set: Average loss: 0.4881	Average nonzero triplets: 962.4615384615385
# Train: [0/5000 (0%)]	Loss: 0.508267	Average nonzero triplets: 960.0
# Train: [12500/5000 (25%)]	Loss: 0.498744	Average nonzero triplets: 1022.7254901960785
# Train: [25000/5000 (50%)]	Loss: 0.499895	Average nonzero triplets: 1031.4158415841584
# Train: [37500/5000 (75%)]	Loss: 0.501329	Average nonzero triplets: 1028.5430463576158
# Epoch: 45/50. Train set: Average loss: 0.5003	Average nonzero triplets: 1025.7537688442212
# Epoch: 45/50. Validation set: Average loss: 0.4894	Average nonzero triplets: 945.9487179487179
# Train: [0/5000 (0%)]	Loss: 0.496840	Average nonzero triplets: 1189.0
# Train: [12500/5000 (25%)]	Loss: 0.501496	Average nonzero triplets: 1030.9803921568628
# Train: [25000/5000 (50%)]	Loss: 0.502758	Average nonzero triplets: 1027.2277227722773
# Train: [37500/5000 (75%)]	Loss: 0.498470	Average nonzero triplets: 1022.8741721854304
# Epoch: 46/50. Train set: Average loss: 0.5012	Average nonzero triplets: 1023.7738693467337
# Epoch: 46/50. Validation set: Average loss: 0.4893	Average nonzero triplets: 951.6410256410256
# Train: [0/5000 (0%)]	Loss: 0.509938	Average nonzero triplets: 988.0
# Train: [12500/5000 (25%)]	Loss: 0.500296	Average nonzero triplets: 1037.5098039215686
# Train: [25000/5000 (50%)]	Loss: 0.498502	Average nonzero triplets: 1029.118811881188
# Train: [37500/5000 (75%)]	Loss: 0.500528	Average nonzero triplets: 1032.3112582781457
# Epoch: 47/50. Train set: Average loss: 0.4998	Average nonzero triplets: 1031.8442211055276
# Epoch: 47/50. Validation set: Average loss: 0.4868	Average nonzero triplets: 981.8205128205128
# Train: [0/5000 (0%)]	Loss: 0.485743	Average nonzero triplets: 945.0
# Train: [12500/5000 (25%)]	Loss: 0.498379	Average nonzero triplets: 1021.2156862745098
# Train: [25000/5000 (50%)]	Loss: 0.500983	Average nonzero triplets: 1024.6039603960396
# Train: [37500/5000 (75%)]	Loss: 0.499717	Average nonzero triplets: 1028.3046357615895
# Epoch: 48/50. Train set: Average loss: 0.4997	Average nonzero triplets: 1025.3969849246232
# Epoch: 48/50. Validation set: Average loss: 0.4873	Average nonzero triplets: 963.8205128205128
# Train: [0/5000 (0%)]	Loss: 0.500615	Average nonzero triplets: 1026.0
# Train: [12500/5000 (25%)]	Loss: 0.500496	Average nonzero triplets: 1028.0
# Train: [25000/5000 (50%)]	Loss: 0.502415	Average nonzero triplets: 1025.3564356435643
# Train: [37500/5000 (75%)]	Loss: 0.499817	Average nonzero triplets: 1024.8079470198675
# Epoch: 49/50. Train set: Average loss: 0.5010	Average nonzero triplets: 1028.788944723618
# Epoch: 49/50. Validation set: Average loss: 0.4878	Average nonzero triplets: 971.8461538461538
# Train: [0/5000 (0%)]	Loss: 0.510539	Average nonzero triplets: 965.0
# Train: [12500/5000 (25%)]	Loss: 0.501868	Average nonzero triplets: 1030.6470588235295
# Train: [25000/5000 (50%)]	Loss: 0.497334	Average nonzero triplets: 1030.6732673267327
# Train: [37500/5000 (75%)]	Loss: 0.501353	Average nonzero triplets: 1029.6490066225165
# Epoch: 50/50. Train set: Average loss: 0.5007	Average nonzero triplets: 1026.532663316583
# Epoch: 50/50. Validation set: Average loss: 0.4914	Average nonzero triplets: 951.8205128205128

# %%
model.eval()
# Out:
# TripletNet(
#   (embedding_net): EmbeddingNet(
#     (convnet): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#       (1): PReLU(num_parameters=1)
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#       (4): PReLU(num_parameters=1)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=1600, out_features=256, bias=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): PReLU(num_parameters=1)
#       (4): Linear(in_features=256, out_features=128, bias=True)
#     )
#   )
# )
